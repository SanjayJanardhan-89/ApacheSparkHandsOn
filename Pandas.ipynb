# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjayJanardhan-89/ApacheSparkHandsOn/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Pyspark

# %%
# !sudo apt update
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
#Check this site for the latest download link https://www.apache.org/dyn/closer.lua/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !wget -q https://dlcdn.apache.org/spark/spark-3.2.1/spark-3.2.1-bin-hadoop3.2.tgz
# !tar xf spark-3.2.1-bin-hadoop3.2.tgz
# !pip install -q findspark
# !pip install pyspark
# !pip install py4j

import os
import sys
# os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# os.environ["SPARK_HOME"] = "/content/spark-3.2.1-bin-hadoop3.2"


import findspark
findspark.init()
findspark.find()

import pyspark
from pyspark.sql import SparkSession

spark= SparkSession \
       .builder \
       .appName("OurSparkApp") \
       .getOrCreate()

spark
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,729 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,387 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import pandas as pd

# %%
data =[["John", 30, "Journalist"],["Mary", 30, "Programmer"],["Abe", 40, "Chef"] ]
df = pd.DataFrame(data)
df
# Out:
#       0   1           2
# 0  John  30  Journalist
# 1  Mary  30  Programmer
# 2   Abe  40        Chef

# %%
data =[["John", 30, "Journalist"],["Mary", 30, "Programmer"],["Abe", 40, "Chef"] ]
df = pd.DataFrame(data, columns=["Name", "Age", "Occupation"])
df
# Out:
#    Name  Age  Occupation
# 0  John   30  Journalist
# 1  Mary   30  Programmer
# 2   Abe   40        Chef

# %%
data =[["John", 30, "Journalist"],["Mary", 30, "Programmer"],["Abe", 40, "Chef"] ]
df_spark = spark.createDataFrame(data,["Name", "Age", "Occupation"])
df_spark.show()
# Out:
# +----+---+----------+
# |Name|Age|Occupation|
# +----+---+----------+
# |John| 30|Journalist|
# |Mary| 30|Programmer|
# | Abe| 40|      Chef|
# +----+---+----------+

# %%
data =[["John", 30, "Journalist"],["Mary", 30, "Programmer"],["Abe", 40, "Chef"] ]
cols = ["Name", "Age", "Occupation"]
df = pd.DataFrame(data=data, columns=cols)
df
# Out:
#    Name  Age  Occupation
# 0  John   30  Journalist
# 1  Mary   30  Programmer
# 2   Abe   40        Chef

# %%
df["Age"]
# Out:
# 0    30
# 1    30
# 2    40
# Name: Age, dtype: int64

# %%
df.Age
# Out:
# 0    30
# 1    30
# 2    40
# Name: Age, dtype: int64

# %%
df["Age"].dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# Name          object
# Age            int64
# Occupation    object
# dtype: object

# %%
df["Age"]+df["Age"]
# Out:
# 0    60
# 1    60
# 2    80
# Name: Age, dtype: int64

# %%
df["Age"]*3
# Out:
# 0     90
# 1     90
# 2    120
# Name: Age, dtype: int64

# %%
df["Age"][2]
# Out:
# np.int64(40)

# %%
df2= df[["Age", "Occupation"]]
df2
# Out:
#    Age  Occupation
# 0   30  Journalist
# 1   30  Programmer
# 2   40        Chef
